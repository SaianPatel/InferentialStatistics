# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load the dataset
df = pd.read_csv("Data/winequality-red.csv")

# %%
x = df['alcohol'].dropna()
y = df['free sulfur dioxide'].dropna()

# %%
# Produce a scatter plot
plt.figure(figsize=(5,4))
plt.scatter(x, y, color="darkblue")
plt.title("Alcohol vs FSD")
plt.xlabel("Alcohol (%)")
plt.ylabel("FSD")
# Out:
# Text(0, 0.5, 'FSD')

# %%
# Compute the correlation matrix
corr_matrix = np.corrcoef(x, y)
print("Correlation matrix:")
print(corr_matrix)

# Extract correlation
corr_xy = corr_matrix[0,1]
print("Correlation betwwen x and y is ", corr_xy)
# Out:
# Correlation matrix:
# [[ 1.         -0.06940835]
#  [-0.06940835  1.        ]]
# Correlation betwwen x and y is  -0.06940835356499989

# %%
# Produce a correlation matrix heatmap

import seaborn as sns
# Compute the correlation matrix
correlation_matrix = df.corr()

# Plot the correlation matrix as a heatmap with numbers
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="RdBu", linewidths=0.5, square=True, cbar=True)

# Title and layout adjustments
plt.title("Correlation Matrix Heatmap", fontsize=14)
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)

# Show the heatmap
plt.show()
